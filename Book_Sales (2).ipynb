# %% [markdown]
# # **TRATAMENTO DOS DADOS**

# %%
import pandas as pd

# %%
df = pd.read_csv("Books_Data_Clean.csv")

# %%
df.head(2)
# Out:
#    index  Publishing Year         Book Name  \
# 0      0           1975.0           Beowulf
# 1      1           1987.0  Batman: Year One
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# 1  Intermediate                 4.23              145267  genre fiction
#
#    gross sales  publisher revenue  sale price  sales rank  \
# 0      34160.0            20496.0        4.88           1
# 1      12437.5             7462.5        1.99           2
#
#                  Publisher   units sold
# 0  HarperCollins Publishers        7000
# 1  HarperCollins Publishers        6250

# %% [markdown]
# ## **Excluindo a coluna "Index"**

# %%
df.head(1)
# Out:
#    index  Publishing Year Book Name                  Author language_code  \
# 0      0           1975.0   Beowulf  Unknown, Seamus Heaney         en-US
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
#
#    gross sales  publisher revenue  sale price  sales rank  \
# 0      34160.0            20496.0        4.88           1
#
#                  Publisher   units sold
# 0  HarperCollins Publishers        7000

# %%
df.drop('index', axis=1, inplace=True)
df.head(1)
# Out:
#    Publishing Year Book Name                  Author language_code  \
# 0           1975.0   Beowulf  Unknown, Seamus Heaney         en-US
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
#
#    gross sales  publisher revenue  sale price  sales rank  \
# 0      34160.0            20496.0        4.88           1
#
#                  Publisher   units sold
# 0  HarperCollins Publishers        7000

# %% [markdown]
# ## **Traduzindo os nomes das colunas**

# %%
colunas_traduzidas = {
    'Publishing Year': 'Ano de Publicação',
    'Book Name': 'Título',
    'Author': 'Autor',
    'language_code': 'Idioma',
    'Author_Rating': 'Nível do Autor',
    'Book_average_rating': 'Avaliação Média',
    'Book_ratings_count': 'Contagem de Avaliações',
    'genre': 'Gênero',
    'gross sales': 'Vendas Brutas',
    'publisher revenue': 'Receita do Editor',
    'sale price': 'Preço de Venda',
    'sales rank': 'Ranking de Vendas',
    'Publisher ': 'Editora',
    'units sold': 'Unidades Vendidas'
}

df.rename(columns=colunas_traduzidas, inplace=True)

# %% [markdown]
# ## **Traduzindo os valores**

# %%
# Nível do Autor

df.replace('Novice', 'Iniciante', inplace=True)
df.replace('Intermediate', 'Intermediário', inplace=True)
df.replace('Famous', 'Famoso', inplace=True)
df.replace('Excellent', 'Excelente', inplace=True)

# Gênero

df.replace('genre fiction', 'Ficção Científica', inplace=True)
df.replace('nonfiction', 'Outro', inplace=True)
df.replace('fiction', 'Ficção Científica', inplace=True)
df.replace('children', 'Infantil', inplace=True)

# Idioma

df.replace('en-US', 'Inglês', inplace=True)
df.replace('en-GB', 'Inglês', inplace=True)
df.replace('en-CA', 'Inglês', inplace=True)
df.replace('eng', 'Inglês', inplace=True)
df.replace('spa', 'Espanhol', inplace=True)
df.replace('fre', 'Francês', inplace=True)
df.replace('nl', 'Holandês', inplace=True)
df.replace('ara', 'Árabe', inplace=True)

## Valores não informados forma definidos como "Outro"

df.Idioma.fillna('Outro', inplace=True)
# Out:
# <ipython-input-7-1b6e04561a01>:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Idioma.fillna('Outro', inplace=True)

# %% [markdown]
# ## **Ano de Publicação com valores nulos**

# %%
df[df['Ano de Publicação'].isnull()]
# Out:
#      Ano de Publicação Título                      Autor Idioma  \
# 445                NaN    NaN  Robert Kapilow, Dr. Seuss  Outro
#
#     Nível do Autor  Avaliação Média  Contagem de Avaliações Gênero  \
# 445         Famoso             4.44                   90574  Outro
#
#      Vendas Brutas  Receita do Editor  Preço de Venda  Ranking de Vendas  \
# 445         532.22            319.332            2.99                493
#
#                  Editora  Unidades Vendidas
# 445  Hachette Book Group               4806

# %%
# Removendo o registro com o Ano de Publicação não informado

df.dropna(subset=['Ano de Publicação'], inplace=True)

# %% [markdown]
# ## **Formatando o "Ano de Publicação" como INT**

# %%
# Alterando o tipo da coluna de FLOAT para INT

df['Ano de Publicação'] = df['Ano de Publicação'].astype(int)

# %% [markdown]
# ## **Excluindo livros publicados antes de Cristo**

# %%
df.sort_values('Ano de Publicação').head(2)
# Out:
#      Ano de Publicação             Título                             Autor  \
# 589               -560           Aesopica  Aesop, Laura Harris, Laura Gibbs
# 990               -441  á¼ˆÎ½Ï„Î¹Î³ÏŒÎ½Î·            Sophocles, J.E. Thomas
#
#      Idioma Nível do Autor  Avaliação Média  Contagem de Avaliações  \
# 589  Inglês      Excelente             4.05                   88508
# 990  Inglês  Intermediário             3.60                   67608
#
#                 Gênero  Vendas Brutas  Receita do Editor  Preço de Venda  \
# 589  Ficção Científica         693.61              0.000            4.99
# 990  Ficção Científica         106.92             64.152            0.99
#
#      Ranking de Vendas                         Editora  Unidades Vendidas
# 589                663  Amazon Digital Services,  Inc.              53784
# 990               1167  Amazon Digital Services,  Inc.                108

# %%
# Excluido livros com "Ano de Publicação" negativo

df.drop(df[df['Ano de Publicação'] < 0].index,  inplace=True)

df.sort_values('Ano de Publicação').head(2)
# Out:
#      Ano de Publicação              Título  \
# 636               1308  La Divina Commedia
# 446               1320             Inferno
#
#                                                  Autor  Idioma Nível do Autor  \
# 636  Dante Alighieri, Allen Mandelbaum, Eugenio Mon...  Inglês      Excelente
# 446                 Dante Alighieri, Anthony M. Esolen   Outro  Intermediário
#
#      Avaliação Média  Contagem de Avaliações             Gênero  \
# 636             4.06                   74130  Ficção Científica
# 446             3.99                   87511  Ficção Científica
#
#      Vendas Brutas  Receita do Editor  Preço de Venda  Ranking de Vendas  \
# 636         124.74              0.000            0.99                720
# 446         354.22            212.532            1.99                493
#
#                             Editora  Unidades Vendidas
# 636  Amazon Digital Services,  Inc.              46008
# 446             Hachette Book Group               4806

# %% [markdown]
# ## **Excluindo livros sem títulos**

# %%
print(f"Existem {df['Título'].isna().sum()} livros sem título")
# Out:
# Existem 22 livros sem título

# %%
df.dropna(subset=['Título'], inplace=True)

# %% [markdown]
# ## **Quantidade de valores não nulos**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1041 entries, 0 to 1069
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Ano de Publicação       1041 non-null   int64
#  1   Título                  1041 non-null   object
#  2   Autor                   1041 non-null   object
#  3   Idioma                  1041 non-null   object
#  4   Nível do Autor          1041 non-null   object
#  5   Avaliação Média         1041 non-null   float64
#  6   Contagem de Avaliações  1041 non-null   int64
#  7   Gênero                  1041 non-null   object
#  8   Vendas Brutas           1041 non-null   float64
#  9   Receita do Editor       1041 non-null   float64
#  10  Preço de Venda          1041 non-null   float64
#  11  Ranking de Vendas       1041 non-null   int64
#  12  Editora                 1041 non-null   object
#  13  Unidades Vendidas       1041 non-null   int64
# dtypes: float64(4), int64(4), object(6)
# memory usage: 122.0+ KB

# %% [markdown]
# # **MANIPULAÇÃO DOS DADOS**

# %% [markdown]
# # **Criando a coluna "Categoria da Avaliação"**

# %%
# Definindo os intervalos
df['Avaliação Média'].quantile([0.33, 0.66])
# Out:
# 0.33    3.91
# 0.66    4.12
# Name: Avaliação Média, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Definindo o tamanho da figura
plt.figure(figsize=(12, 3))

# Criando o histograma
sns.histplot(df['Avaliação Média'], kde=True)

# Criando as linhas
plt.axvline(x=3.91, color='red', linestyle='--', linewidth=1.8)
plt.axvline(x=4.12, color='red', linestyle='--', linewidth=1.8)

# Criando os textos
plt.text(x=3.25, y = 110, s='Baixa', color='red', fontsize = 11)
plt.text(x=3.97, y = 110, s='Média', color='red', fontsize = 11)
plt.text(x=4.5, y = 110, s='Alta', color='red', fontsize = 11)

# %%
df['Categoria de Avaliação'] = pd.cut(df['Avaliação Média'], bins=[0, 3.91, 4.12, 5], labels=['Baixa', 'Média', 'Alta'])

df.head(2)
# Out:
#    Ano de Publicação            Título  \
# 0               1975           Beowulf
# 1               1987  Batman: Year One
#
#                                                Autor  Idioma Nível do Autor  \
# 0                             Unknown, Seamus Heaney  Inglês      Iniciante
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...  Inglês  Intermediário
#
#    Avaliação Média  Contagem de Avaliações             Gênero  Vendas Brutas  \
# 0             3.42                  155903  Ficção Científica        34160.0
# 1             4.23                  145267  Ficção Científica        12437.5
#
#    Receita do Editor  Preço de Venda  Ranking de Vendas  \
# 0            20496.0            4.88                  1
# 1             7462.5            1.99                  2
#
#                     Editora  Unidades Vendidas Categoria de Avaliação
# 0  HarperCollins Publishers               7000                  Baixa
# 1  HarperCollins Publishers               6250                   Alta

# %%
df['Categoria de Avaliação'].value_counts()
# Out:
# Categoria de Avaliação
# Baixa    359
# Alta     346
# Média    336
# Name: count, dtype: int64

# %% [markdown]
# # **ANÁLISE DE DADOS**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df['Ano de Publicação'], bins = 100)
plt.show()

# %%
print(f"A média das avaliação dos livros é de {round(df['Avaliação Média'].mean(), 4)}")
# Out:
# A média das avaliação dos livros é de 4.0032

# %%
print(f"A média de preço dos livros é de ${round(df['Preço de Venda'].mean(), 4)}")
# Out:
# A média de preço dos livros é de $4.8497

# %%
plt.bar(df['Nível do Autor'].value_counts().index, df['Nível do Autor'].value_counts())
plt.show()

# %%
df.columns
# Out:
# Index(['Ano de Publicação', 'Título', 'Autor', 'Idioma', 'Nível do Autor',
#        'Avaliação Média', 'Contagem de Avaliações', 'Gênero', 'Vendas Brutas',
#        'Receita do Editor', 'Preço de Venda', 'Ranking de Vendas', 'Editora',
#        'Unidades Vendidas', 'Categoria de Avaliação'],
#       dtype='object')
